# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1 = pd.read_csv('train.csv')
#删除NA多的数据col
df2 = df1.drop(['Cabin'],axis = 1)
#填充缺失数据
df2['Age'] = df2['Age'].fillna(20)
#删除Embarked为Na的行
df2 = df2.loc[df2['Embarked'].notnull()]

# %%
#可以对index和columns进行限制,获得感兴趣的数据
df1.loc[11:15,['Age','Embarked']]
# Out:
#      Age Embarked
# 11  58.0        S
# 12  20.0        S
# 13  39.0        S
# 14  14.0        S
# 15  55.0        S

# %%
df2.pivot_table(values = 'PassengerId',index = 'Survived',columns = 'Sex',aggfunc = 'count')
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            231   109

# %%
df2.loc[df1['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
df2.loc[df1['Age']>20]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 25            26         1       3
# 30            31         0       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# 40            41         0       3
# 41            42         0       2
# 51            52         0       3
# 52            53         1       1
# 53            54         1       2
# ...

# %%
#Merge方法对两个pandas片段进行融合,on是融合依据，how是选择的融合方式
df3 = df2[['PassengerId','Name']].merge(df1[['PassengerId','Cabin']],on = 'PassengerId',how = 'outer')

# %%
print(df1.shape)
print(df2.shape)
df3.shape
# Out:
# (891, 12)
# (889, 11)
# (891, 3)

# %%
pd.value_counts()

# %%
#求Person互相关,
df2['Survived'].
# Out:
# 1    214
# 2    184
# 3    491
# Name: Pclass, dtype: int64
